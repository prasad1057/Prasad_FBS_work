# %%
import pandas as pd

# %%
iris = pd.read_csv(r"D:\FBS\Data Analysis\Datasets\Iris.csv")
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
s1 = iris['Sepal_Length']
s1
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Sepal_Length, Length: 150, dtype: float64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1[0]
# Out:
# 5.1

# %%
s1[0:5]
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: Sepal_Length, dtype: float64

# %%
i2 = iris.set_index(iris['Sepal_Length'])
i2
# Out:
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# Sepal_Length
# 5.1                    5.1          3.5           1.4          0.2     Setosa
# 4.9                    4.9          3.0           1.4          0.2     Setosa
# 4.7                    4.7          3.2           1.3          0.2     Setosa
# 4.6                    4.6          3.1           1.5          0.2     Setosa
# 5.0                    5.0          3.6           1.4          0.2     Setosa
# ...                    ...          ...           ...          ...        ...
# 6.7                    6.7          3.0           5.2          2.3  Virginica
# 6.3                    6.3          2.5           5.0          1.9  Virginica
# 6.5                    6.5          3.0           5.2          2.0  Virginica
# 6.2                    6.2          3.4           5.4          2.3  Virginica
# 5.9                    5.9          3.0           5.1          1.8  Virginica
#
# ...

# %%
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris[0:2]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %%
iris.loc[:, 'Sepal_Length']         #[row, cloumn]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Sepal_Length, Length: 150, dtype: float64

# %%
iris.iloc[:, 1]             #[row, column]
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: Sepal_Width, Length: 150, dtype: float64

# %%
iris.iloc[:, 0:-1]
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris.iloc[:, -1]
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: Species, Length: 150, dtype: object

# %%
y = iris['Sepal_Width']
y
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: Sepal_Width, Length: 150, dtype: float64

# %%
x = iris.drop('Sepal_Width', axis=1)
x
# Out:
#      Sepal_Length  Petal_Length  Petal_Width    Species
# 0             5.1           1.4          0.2     Setosa
# 1             4.9           1.4          0.2     Setosa
# 2             4.7           1.3          0.2     Setosa
# 3             4.6           1.5          0.2     Setosa
# 4             5.0           1.4          0.2     Setosa
# ..            ...           ...          ...        ...
# 145           6.7           5.2          2.3  Virginica
# 146           6.3           5.0          1.9  Virginica
# 147           6.5           5.2          2.0  Virginica
# 148           6.2           5.4          2.3  Virginica
# 149           5.9           5.1          1.8  Virginica
#
# [150 rows x 4 columns]
