# %%
import pandas as pd

# %%
emp = pd.DataFrame({'Name':['Akshay', 'Rohit', 'Virat', 'John', 'Michael'],
                   'Age':[32, 45, 28, 32, 27],
                   'Salary':[45000, 38000, 29000, 50000, 41000]
                   })
emp
# Out:
#       Name  Age  Salary
# 0   Akshay   32   45000
# 1    Rohit   45   38000
# 2    Virat   28   29000
# 3     John   32   50000
# 4  Michael   27   41000

# %%
emp['Salary'].mean()
# Out:
# 40600.0

# %%
emp['Salary'].median()
# Out:
# 41000.0

# %%
emp['Salary'].mode()
# Out:
# 0    29000
# 1    38000
# 2    41000
# 3    45000
# 4    50000
# Name: Salary, dtype: int64

# %%
emp['Age'].mode()
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
emp['Age'].unique()
# Out:
# array([32, 45, 28, 27], dtype=int64)

# %%
emp['Age'].value_counts()               #count of unique values
# Out:
# Age
# 32    2
# 45    1
# 28    1
# 27    1
# Name: count, dtype: int64

# %%
emp['DID'] = [1, 2, 2, 3, 4]            #add new column (but it add in the last)
emp
# Out:
#       Name  Age  Salary  DID  dud
# 0   Akshay   32   45000    1    1
# 1    Rohit   45   38000    2    2
# 2    Virat   28   29000    2    3
# 3     John   32   50000    3    1
# 4  Michael   27   41000    4    4

# %%
emp
# Out:
#       Name  Age  Salary  DID
# 0   Akshay   32   45000    1
# 1    Rohit   45   38000    2
# 2    Virat   28   29000    2
# 3     John   32   50000    3
# 4  Michael   27   41000    4

# %%
emp.insert(2, value = ['Pune','Mumbai','CSN', 'Nashik', 'Akola'], column='Address')

# %%
emp
# Out:
#       Name  Age Address  Salary  DID
# 0   Akshay   32    Pune   45000    1
# 1    Rohit   45  Mumbai   38000    2
# 2    Virat   28     CSN   29000    2
# 3     John   32  Nashik   50000    3
# 4  Michael   27   Akola   41000    4

# %% [markdown]
# here if we do without loc() then it will add as a column
# but now we used loc() then it will add as a row

# %%
emp.loc[len(emp)] = ['Roshan', 67, 'Pune', 100000, 1]

# %%
emp
# Out:
#        Name  Age Address  Salary  DID
# 0    Akshay   32    Pune   45000    1
# 1     Rohit   45  Mumbai   38000    2
# 2     Virat   28     CSN   29000    2
# 3      John   32  Nashik   50000    3
# 4   Michael   27   Akola   41000    4
# 5    Roshan   67    Pune  100000    1
# 10   Roshan   67    Pune  100000    1

# %%
len(emp)
# Out:
# 6

# %%
#emp = emp.drop(10)
emp.drop(10, inplace=True)          #inplace means change directly into original

# %% [markdown]
# specific value change

# %%
emp.loc[emp['Name'] == 'Rohit', 'Salary'] = 80000            #(location, what to change) = updated value

# %%
emp
# Out:
#       Name  Age Address  Salary  DID
# 0   Akshay   32    Pune   45000    1
# 1    Rohit   45  Mumbai   80000    2
# 2    Virat   28     CSN   29000    2
# 3     John   32  Nashik   50000    3
# 4  Michael   27   Akola   41000    4
# 5   Roshan   67    Pune  100000    1

# %%
emp.loc[emp['Name'] == 'John']
# Out:
#    Name  Age Address  Salary  DID
# 3  John   32  Nashik   50000    3
