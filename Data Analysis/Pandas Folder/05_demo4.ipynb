# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\FBS\Data Analysis\Datasets\student_10.csv")
data
# Out:
#          Date  Student ID  Class  Study hrs  Percentage
# 0  01-07-2021      1001.0     10        2.0        50.0
# 1  02-07-2021      1002.0     10        6.0        80.0
# 2  03-07-2021         NaN     10        3.0        60.0
# 3  06-07-2021         NaN     11        0.0         NaN
# 4  07-07-2021      1005.0     11        4.0         NaN
# 5  08-07-2021         NaN     11       10.0         NaN
# 6  09-07-2021      1007.0     12        4.0        80.0
# 7  10-07-2021      1008.0     12        NaN        90.0
# 8  11-07-2021      1009.0     12        NaN        60.0
# 9  12-07-2021      1010.0     12        6.0        85.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        10 non-null     object
#  1   Student ID  7 non-null      float64
#  2   Class       10 non-null     int64
#  3   Study hrs   8 non-null      float64
#  4   Percentage  7 non-null      float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 532.0+ bytes

# %%
data.isnull()
# Out:
#     Date  Student ID  Class  Study hrs  Percentage
# 0  False       False  False      False       False
# 1  False       False  False      False       False
# 2  False        True  False      False       False
# 3  False        True  False      False        True
# 4  False       False  False      False        True
# 5  False        True  False      False        True
# 6  False       False  False      False       False
# 7  False       False  False       True       False
# 8  False       False  False       True       False
# 9  False       False  False      False       False

# %%
data.isnull().sum()     #column wise null values
# Out:
# Date          0
# Student ID    3
# Class         0
# Study hrs     2
# Percentage    3
# dtype: int64

# %%
data.dropna()           #drop the row having any null value
# Out:
#          Date  Student ID  Class  Study hrs  Percentage
# 0  01-07-2021      1001.0     10        2.0        50.0
# 1  02-07-2021      1002.0     10        6.0        80.0
# 6  09-07-2021      1007.0     12        4.0        80.0
# 9  12-07-2021      1010.0     12        6.0        85.0

# %%
data.dropna(axis=1)
# Out:
#          Date  Class
# 0  01-07-2021     10
# 1  02-07-2021     10
# 2  03-07-2021     10
# 3  06-07-2021     11
# 4  07-07-2021     11
# 5  08-07-2021     11
# 6  09-07-2021     12
# 7  10-07-2021     12
# 8  11-07-2021     12
# 9  12-07-2021     12

# %%
data2 = data.drop(['Date', 'Student ID'], axis=1)
data2
# Out:
#    Class  Study hrs  Percentage
# 0     10        2.0        50.0
# 1     10        6.0        80.0
# 2     10        3.0        60.0
# 3     11        0.0         NaN
# 4     11        4.0         NaN
# 5     11       10.0         NaN
# 6     12        4.0        80.0
# 7     12        NaN        90.0
# 8     12        NaN        60.0
# 9     12        6.0        85.0

# %%
study_hr = data2['Study hrs'].mean()
study_hr
# Out:
# 4.375

# %%
data2.fillna(0)
# Out:
#    Class  Study hrs  Percentage
# 0     10        2.0        50.0
# 1     10        6.0        80.0
# 2     10        3.0        60.0
# 3     11        0.0         0.0
# 4     11        4.0         0.0
# 5     11       10.0         0.0
# 6     12        4.0        80.0
# 7     12        0.0        90.0
# 8     12        0.0        60.0
# 9     12        6.0        85.0

# %%
percen = data2['Percentage'].mean()
percen
# Out:
# 72.14285714285714

# %%
data2.fillna({'Study hrs': study_hr, 'Percentage': percen})
# Out:
#    Class  Study hrs  Percentage
# 0     10      2.000   50.000000
# 1     10      6.000   80.000000
# 2     10      3.000   60.000000
# 3     11      0.000   72.142857
# 4     11      4.000   72.142857
# 5     11     10.000   72.142857
# 6     12      4.000   80.000000
# 7     12      4.375   90.000000
# 8     12      4.375   60.000000
# 9     12      6.000   85.000000

# %%
data2.fillna(method='bfill')

#data2.bfill()


#data2.fillna(method='bfill)        deprecated in modern version of python
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11208\1757425626.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2.fillna(method='bfill')
#    Class  Study hrs  Percentage
# 0     10        2.0        50.0
# 1     10        6.0        80.0
# 2     10        3.0        60.0
# 3     11        0.0        80.0
# 4     11        4.0        80.0
# 5     11       10.0        80.0
# 6     12        4.0        80.0
# 7     12        6.0        90.0
# 8     12        6.0        60.0
# 9     12        6.0        85.0

# %%
data2.bfill()           #below value fill into Nan values
# Out:
#    Class  Study hrs  Percentage
# 0     10        2.0        50.0
# 1     10        6.0        80.0
# 2     10        3.0        60.0
# 3     11        0.0        80.0
# 4     11        4.0        80.0
# 5     11       10.0        80.0
# 6     12        4.0        80.0
# 7     12        6.0        90.0
# 8     12        6.0        60.0
# 9     12        6.0        85.0

# %%
data3 = data2.ffill()         #above value fill into Nan values

# %%
data3
# Out:
#    Class  Study hrs  Percentage
# 0     10        2.0        50.0
# 1     10        6.0        80.0
# 2     10        3.0        60.0
# 3     11        0.0        60.0
# 4     11        4.0        60.0
# 5     11       10.0        60.0
# 6     12        4.0        80.0
# 7     12        4.0        90.0
# 8     12        4.0        60.0
# 9     12        6.0        85.0

# %%
groups = data3.groupby('Class')

# %%
list(groups)
# Out:
# [(10,
#      Class  Study hrs  Percentage
#   0     10        2.0        50.0
#   1     10        6.0        80.0
#   2     10        3.0        60.0),
#  (11,
#      Class  Study hrs  Percentage
#   3     11        0.0        60.0
#   4     11        4.0        60.0
#   5     11       10.0        60.0),
#  (12,
#      Class  Study hrs  Percentage
#   6     12        4.0        80.0
#   7     12        4.0        90.0
#   8     12        4.0        60.0
#   9     12        6.0        85.0)]

# %%
di = dict(list(groups))
di
# Out:
# {10:    Class  Study hrs  Percentage
#  0     10        2.0        50.0
#  1     10        6.0        80.0
#  2     10        3.0        60.0,
#  11:    Class  Study hrs  Percentage
#  3     11        0.0        60.0
#  4     11        4.0        60.0
#  5     11       10.0        60.0,
#  12:    Class  Study hrs  Percentage
#  6     12        4.0        80.0
#  7     12        4.0        90.0
#  8     12        4.0        60.0
#  9     12        6.0        85.0}

# %%
gr_10 = groups.get_group(10)           #access particular group
gr_11 = groups.get_group(11)
gr_12 = groups.get_group(12)

# %%
gr_10['Study hrs'].mean()
# Out:
# 3.6666666666666665

# %%
gr = dict(list(data3.groupby(['Class', 'Study hrs'])))
gr
# Out:
# {(10,
#   2.0):    Class  Study hrs  Percentage
#  0     10        2.0        50.0,
#  (10,
#   3.0):    Class  Study hrs  Percentage
#  2     10        3.0        60.0,
#  (10,
#   6.0):    Class  Study hrs  Percentage
#  1     10        6.0        80.0,
#  (11,
#   0.0):    Class  Study hrs  Percentage
#  3     11        0.0        60.0,
#  (11,
#   4.0):    Class  Study hrs  Percentage
#  4     11        4.0        60.0,
#  (11,
#   10.0):    Class  Study hrs  Percentage
#  5     11       10.0        60.0,
#  (12,
#   4.0):    Class  Study hrs  Percentage
#  6     12        4.0        80.0
#  7     12        4.0        90.0
#  8     12        4.0        60.0,
#  (12,
#   6.0):    Class  Study hrs  Percentage
#  9     12        6.0        85.0}
