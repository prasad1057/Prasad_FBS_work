# %%
print('This is first line')
# Out:
# This is first line

# %% [markdown]
# # Heading
# ## Heading
# ### Heading

# %% [markdown]
# ### Basic Shortcut for notebook
#
# 1. a is used to add cell above
# 2. b is used to add cell below
# 3. dd - delete cell
# 4. y - code
# 5. shift + enter : execute curren cell and adding new cell
# 6. ctrl + enter : execute current cell only

# %% [markdown]
# #### Numpy
#
#
# 1. Scientific computing library - Numeric python
# 2. Build with python + C
# 3. Used for multidimensional array, matrix
# 4. Used for mathematical calculations

# %%
li1 = [1,2]
li2 = [3,4]
li1,li2
# Out:
# ([1, 2], [3, 4])

# %%
li1 + li2
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# #### Numpy Array v/s Python List

# %% [markdown]
# #### Speed

# %%
# %%time

li1 = list(range(1, 100001))
li2 = list(range(2, 100002))
li3 = []

for i in range(len(li1)):
    li3.append(li1[i] + li2[i])
# Out:
# CPU times: total: 62.5 ms
# Wall time: 60 ms

# %%
import numpy as np

# %%
# %%time

arr1 = np.arange(1, 100001)
arr2 = np.arange(2, 100002)

arr1 + arr2
# Out:
# CPU times: total: 15.6 ms
# Wall time: 3.02 ms
# array([     3,      5,      7, ..., 199997, 199999, 200001])
